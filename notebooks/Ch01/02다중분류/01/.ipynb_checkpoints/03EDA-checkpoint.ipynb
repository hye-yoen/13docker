# %%
#----------------
# 2. 라이브러리 가져오기
#------------------

# %%
import pandas as pd

train = pd.read_csv("./train.csv")
test = pd.read_csv("./test.csv")

# %%
# test

# %%
#--------------
# EDA
#--------------

# %%
train.head()
train.tail()
train.sample(5)
# Out:
#       Delay_from_due_date  Num_of_Delayed_Payment  Num_Credit_Inquiries  \
# 427                  13.0                     0.0                   0.0
# 5970                 48.0                    24.0                  13.0
# 1198                 11.0                     6.0                   1.0
# 6495                 25.0                    19.0                   5.0
# 8838                 45.0                    23.0                   9.0
#
#       Credit_Utilization_Ratio  Credit_History_Age Payment_of_Min_Amount  \
# 427                  29.411201               222.0                    No
# 5970                 24.372083               152.0                   Yes
# 1198                 23.265767               302.0                    No
# 6495                 38.291532               163.0                    NM
# 8838                 36.983109               241.0                   Yes
#
#       Amount_invested_monthly  Monthly_Balance  Credit_Score Credit_Mix  ...  \
# ...
